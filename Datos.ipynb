# %% [markdown]
# # Acceso a los datos de encefalogramas

# %%
import scipy.io
# Lectura de cada archivo
arch1 = scipy.io.loadmat('/data/encef/Dog_5/Dog_5_interictal_segment_0450.mat')

# %%
# Todos los archivos
# !ls /data/encef/*

# %%
# los datos en cada archivo
arch1?

# %%
datos = arch1[arch1.keys()[0]]
# para ver el objeto en el que vienen los datos, con: datos?

# %%
# Para graficar los datos son 15 lecturas (no 8 !)
import matplotlib.pyplot as plt

for i in range(15):
    plt.plot(datos[0][0][0][0])
    plt.ylabel('Dog 5 interictal 450 lectura '+str(i))
    plt.show()

# %%
# Transformada de Fourier y su gráfica
from scipy.fftpack import fft
transf_datos = fft(datos[0][0][0][6])
plt.plot(transf_datos)
plt.xlabel('Transformada de Fourier lectura 6')
plt.show()
# Out:
# /home/ubuntu/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
# Procesamiento de señales
# para mas "paquetes/funciones" ver: http://docs.scipy.org/doc/scipy/reference/tutorial/index.html
from scipy.signal import periodogram
for i in range(15):
    f, Pper_spec = periodogram(fft(datos[0][0][0][i]))
    plt.plot(f, Pper_spec)
    plt.xlabel('frequency [Hz]')
    plt.ylabel('PSD '+ str(i))
    plt.grid()
    plt.show()

# %%
periodogram?
