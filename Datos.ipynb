# %% [markdown]
# # Acceso a los datos de encefalogramas

# %%
import scipy.io
# Lectura de cada archivo
arch1 = scipy.io.loadmat('/data/encef/Dog_5/Dog_5_interictal_segment_0450.mat')

# %%
# Todos los archivos
# !ls /data/encef/*

# %%
# los datos en cada archivo
arch1?

# %%
datos = arch1[arch1.keys()[0]]
datos?

# %%
# Para graficar los datos son 14 lecturas (no 8 !)
import matplotlib.pyplot as plt
plt.plot(datos[0][0][0][0])
plt.ylabel('Dog 5 interictal 450 lectura 0')
plt.show()

# %%
plt.plot(datos[0][0][0][14])
plt.ylabel('Dog 5 interictal 450 lectura 14')
plt.show()

# %%
from scipy.fftpack import fft
transf_datos = fft(datos[0][0][0][0])
plt.plot(transf_datos)
plt.xlabel('Transformada de Fourier lectura 0')
plt.show()
# Out:
# /home/ubuntu/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
transf_datos = fft(datos[0][0][0][14])
plt.plot(transf_datos)
plt.xlabel('Transformada de Fourier lectura 14')
plt.show()
