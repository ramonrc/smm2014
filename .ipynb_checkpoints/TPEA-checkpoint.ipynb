# %% [markdown]
# ### Introduccion de los datos del "junior" en dos listas

# %%
import pandas.io.excel
import numpy as np
Li=[]   # Lecturas
Lo=[]   # Ocupacion
for i in np.arange(0, 9, 1):
  Li.append(pandas.io.excel.read_excel("file://localhost/home/ubuntu/notebook/CopiaGasMensual.xls",
                                       sheetname=i, header=1, skip_rows=[0,1,2,3], parse_cols="K:L",
                                       skip_footer=45))
for i in np.arange(0, 9, 1):
  Lo.append(pandas.io.excel.read_excel("file://localhost/home/ubuntu/notebook/CopiaGasMensual.xls",
                                       sheetname=i, header=45, skip_rows=45, parse_cols="L:M",
                                       skip_footer=1))

# %% [markdown]
# ### Calculo del consumo diario

# %%
for i in np.arange(0, 9, 1):
    Lo[i]['CONSUMO']=0
    for key in Li[i].keys():
        j = 1
        while j < Lo[i]['OCUPACION'].count():
            Lo[i]['CONSUMO'][j] += Li[i][key][j+1]-Li[i][key][j]
            j += 1

# %% [markdown]
# ### Graficas de ocupacion-consumo

# %%
Li[i]
# Out:
#     CALENTADOR 081341936  CALEMTADOR 091342072
# 0                    NaN                   NaN
# 1               1912.898              2084.495
# 2               1923.784              2084.495
# 3               1923.784              2094.282
# 4               1923.784              2108.537
# 5               1923.784              2121.862
# 6               1923.784              2145.128
# 7               1923.784              2158.327
# 8               1923.784              2181.717
# 9               1923.784              2199.535
# 10              1923.784              2217.728
# 11              1923.784              2232.137
# 12              1923.784              2252.138
# 13              1923.784              2269.168
# 14              1923.784              2288.520
# 15              1923.784              2305.913
# 16              1941.816              2305.913
# 17              1960.993              2305.913
# 18              1981.319              2305.913
# 19              2002.113              2305.913
# 20              2015.188              2305.913
# 21              2032.032              2305.913
# 22              2047.123              2305.913
# 23              2059.837              2305.913
# 24              2074.776              2305.913
# 25              2091.347              2305.913
# 26              2108.917              2305.913
# 27              2124.552              2305.913
# 28              2134.535              2305.913
# 29              2151.124              2305.913
# 30              2167.516              2305.913
# 31              2183.983              2305.913

# %%
Lo[i]
# Out:
#           LTS  OCUPACION  CONSUMO
# 0         NaN        NaN        0
# 1   42.422742         54       10
# 2   38.139939         41        9
# 3   55.551735         36       14
# 4   51.927525         23       13
# 5   90.667602         21       23
# 6   51.436503         41       13
# 7   91.150830        104       23
# 8   69.436746         83       17
# 9   70.898121         78       18
# 10  56.151873         55       14
# 11  77.943897         47       20
# 12  66.365910         24       17
# 13  75.414744         62       19
# 14  67.780521         69       17
# 15  70.270704        113       18
# 16  74.732769        113       19
# 17  79.210422         93       20
# 18  81.034218         98       20
# 19  50.953275         47       13
# 20  65.641068         69       16
# 21  58.809627         56       15
# 22  49.546458         56       12
# 23  58.217283         44       14
# 24  64.577187         45       16
# 25  68.470290         60       17
# 26  60.929595         29       15
# 27  38.903751         44        9
# 28  64.647333         53       16
# 29  63.879624         66       16
# 30  64.171899         67       16
# 31  61.860978         37        0

# %%
import matplotlib.pyplot as plt
for i in np.arange(0, 9, 1):
    #plt.plot(Lo[i]['OCUPACION'].values, Lo[i]['LTS'].values, 'go')
    plt.plot(Lo[i]['OCUPACION'].values, Lo[i]['CONSUMO'].values/Lo[i]['OCUPACION'].values, 'ro')
    plt.plot(Lo[i]['OCUPACION'].values, Lo[i]['LTS'].values/Lo[i]['OCUPACION'].values, 'yo')
    #plt.plot(Lo[i]['OCUPACION'].values, Lo[i]['CONSUMO'].values, 'bo')
    plt.axis([0, 100, 0, 6])
plt.show()
